# %% [markdown]
# # Importing Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Introduction to Matplotlib

# %% [markdown]
# # Plotting Simplest Plot

# %%
plt.plot([1,2,3,4], 'go-') # IF single parameter is given it is taken as y.

# %% [markdown]
# # Plotting a line with 2 paramenters

# %%
plt.plot([1,2,3,4],[5,9,7,8],'bs-') # 2 Parameters in the order x and y

# %% [markdown]
# # Plyplot basic functions

# %%
x=np.linspace(-8,8,200) #np-> numpy
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.legend(['Cos(x)','Sin(x)'])
plt.xlim(-7,6)
plt.ylim(-1,1)
plt.title('Sin Graph')
plt.show()

# %%
x = [5,8,10]
y = [12,16,6]

plt.plot(x,y)
plt.title('Epic Info')
plt.ylabel('Y axis')
plt.xlabel('X axis')
plt.show()

# %% [markdown]
# # Linewidth  Parameter in plt.plot() function

# %%
x = [5,8,10]
y = [12,16,6]

x2 = [6,9,11]
y2 = [6,15,7]

# can plot specifically, after just showing the defaults:
plt.plot(x,y,linewidth=5)
plt.plot(x2,y2,linewidth=5)

plt.title('Epic Info')
plt.ylabel('Y axis')
plt.xlabel('X axis')

plt.show()

# %% [markdown]
# # Adding axis to a figure

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,2,1]) #x0,y0,width,height
plt.show()

# %% [markdown]
# # Figure, Axis, Ticks

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)

majorLocator = MultipleLocator(20)
majorFormatter = FormatStrFormatter('%d')
minorLocator = MultipleLocator(5)


t = np.arange(0.0, 100.0, 0.1)
s = np.sin(0.1 * np.pi * t) * np.exp(-t * 0.01)

fig, ax = plt.subplots()
ax.plot(t, s)

ax.xaxis.set_major_locator(majorLocator)
ax.xaxis.set_major_formatter(majorFormatter)

# for the minor ticks, use no labels; default NullFormatter
ax.xaxis.set_minor_locator(minorLocator)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter, AutoMinorLocator)

majorLocator = MultipleLocator(20)
majorFormatter = FormatStrFormatter('%d')
minorLocator = MultipleLocator(5)


t = np.arange(0.0, 100.0, 0.1)
s = np.sin(0.1 * np.pi * t) * np.exp(-t * 0.01)

fig, ax = plt.subplots()
ax.plot(t, s)

ax.xaxis.set_major_locator(majorLocator)
ax.xaxis.set_major_formatter(majorFormatter)

# for the minor ticks, use no labels; default NullFormatter
ax.xaxis.set_minor_locator(minorLocator)

ax.tick_params(which='both', width=2)
ax.tick_params(which='major', length=7)
ax.tick_params(which='minor', length=4, color='r')

plt.show()

# %% [markdown]
# # Lineplot

# %%
a=plt.plot([1,2,3,4],[1,2,1,2])

# %%
a=plt.plot([1,2,3,4],[1,2,1,2],'ro-')

# %%
a=plt.plot([1,2,3,4],[1,2,1,2],'b+-')

# %%
a=plt.plot([1,2,1,2],'b+')# plot y using x as index array 0..N-1

# %%
import numpy as np

# %%
x=np.linspace(-8,8,200)#The linspace function generates linearly spaced vectors.
x
# Out:
# array([-8.        , -7.91959799, -7.83919598, -7.75879397, -7.67839196,
#        -7.59798995, -7.51758794, -7.43718593, -7.35678392, -7.27638191,
#        -7.1959799 , -7.11557789, -7.03517588, -6.95477387, -6.87437186,
#        -6.79396985, -6.71356784, -6.63316583, -6.55276382, -6.47236181,
#        -6.3919598 , -6.31155779, -6.23115578, -6.15075377, -6.07035176,
#        -5.98994975, -5.90954774, -5.82914573, -5.74874372, -5.66834171,
#        -5.5879397 , -5.50753769, -5.42713568, -5.34673367, -5.26633166,
#        -5.18592965, -5.10552764, -5.02512563, -4.94472362, -4.86432161,
#        -4.7839196 , -4.70351759, -4.62311558, -4.54271357, -4.46231156,
#        -4.38190955, -4.30150754, -4.22110553, -4.14070352, -4.06030151,
#        -3.9798995 , -3.89949749, -3.81909548, -3.73869347, -3.65829146,
#        -3.57788945, -3.49748744, -3.41708543, -3.33668342, -3.25628141,
#        -3.1758794 , -3.09547739, -3.01507538, -2.93467337, -2.85427136,
# ...

# %% [markdown]
# # Label, Limit, and title function

# %%
plt.plot(x,np.sin(x))
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.legend(['Sin(x)'])
plt.xlim(-7,6)
plt.ylim(0,1)
plt.title('Sin Graph')
plt.show()

# %% [markdown]
# # Bar Plot

# %%
x=np.random.randint(50,size=6)
y=np.random.randint(50,size=6)

# %%
x
# Out:
# array([32, 15, 20,  3, 22, 47])

# %%
y
# Out:
# array([24, 35, 18,  3, 45, 43])

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# # Horizontal Bar Plot

# %%
x=np.random.randint(50,size=6)
y=np.random.randint(50,size=6)
plt.barh(x,y)
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# # Scatter Plot

# %%
x=range(50)
y=np.random.randint(10,size=50)
plt.scatter(x,y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Scatter Plot')

# %% [markdown]
# # Histogram

# %%
x=range(0,60,3)
y=np.random.randint(50,size=500)

# %%
y=sorted(y)

# %%
plt.hist(y,bins=x,color='r')
plt.title('Histogram')
plt.xlabel('Element')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(y,bins=[10,20,30,50],color='y')
plt.title('Histogram')
plt.xlabel('Element')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(y,bins=[10,15,20,30,35,45,50],color='y')
plt.title('Histogram')
plt.xlabel('Element')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(y,bins=10,color='y')
plt.title('Histogram')
plt.xlabel('Element')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # Boxplot

# %%
x=np.random.randint(50,size=50)
print(x)
plt.boxplot(x,1)
plt.title('Box Plot')
plt.xlabel('X')
plt.ylabel('Scale')
# Out:
# [28 10 29 26  8 28 36  8  9 28 22 13 18 29 45 21 28  0 14 17 23 13 23 36
#  19 36 11 26 47  4 30 28 28  0  0  2 46 45 10  9 26 43  2 25 25 36 43 26
#  31 41]
# Text(0, 0.5, 'Scale')

# %% [markdown]
# # Pie Chart

# %%
x=np.random.randint(50,size=10)
y = np.sort(x)

# %%
y=np.zeros(10)
y[0]=.2

# %%
x=np.random.randint(50,size=10)
label=['A','B','C','D','E','F','G','H','I','J']
plt.pie(x,labels=label)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e441d909b0>,
# ...
#  [Text(1.0089324334399594, 0.43824119472377554, 'A'),
#   Text(0.5822031448744754, 0.9332949684308122, 'B'),
#   Text(0.05006607283850631, 1.0988600403830004, 'C'),
#   Text(-0.7778174593052023, 0.7778174593052024, 'D'),
#   Text(-1.0840054683476792, -0.18690143015057142, 'E'),
#   Text(-0.8839942307201819, -0.6546405120777616, 'F'),
#   Text(-0.46109419803658047, -0.998695219041827, 'G'),
#   Text(0.5927884713745352, -0.9266076991939157, 'H'),
#   Text(0.9986952244381715, -0.46109418634850585, 'I'),
#   Text(1.079470110537173, -0.21152843888438216, 'J')])

# %%
label=['A','B','C','D','E','F','G','H','I','J']
plt.pie(x,explode=y,labels=label,autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1e4419ae400>,
# ...
#  [Text(1.1923746940654065, 0.5179214119462802, 'A'),
#   Text(0.5822031448744754, 0.9332949684308122, 'B'),
#   Text(0.05006607283850631, 1.0988600403830004, 'C'),
#   Text(-0.7778174593052023, 0.7778174593052024, 'D'),
#   Text(-1.0840054683476792, -0.18690143015057142, 'E'),
#   Text(-0.8839942307201819, -0.6546405120777616, 'F'),
#   Text(-0.46109419803658047, -0.998695219041827, 'G'),
#   Text(0.5927884713745352, -0.9266076991939157, 'H'),
#   Text(0.9986952244381715, -0.46109418634850585, 'I'),
#   Text(1.079470110537173, -0.21152843888438216, 'J')],
#  [Text(0.7337690425017886, 0.31872086889001855, '13.04%'),
#   Text(0.31756535174971384, 0.5090699827804429, '6.16%'),
#   Text(0.02730876700282162, 0.599378203845273, '10.14%'),
#   Text(-0.42426406871192845, 0.4242640687119285, '16.30%'),
#   Text(-0.5912757100078249, -0.1019462346275844, '14.13%'),
#   Text(-0.4821786713019173, -0.3570766429515063, '0.72%'),
# ...

# %% [markdown]
# # Adding Subplots to a figure

# %%
fig = plt.figure(figsize=(5,5))

fig.add_subplot(221)
fig.add_subplot(222)
# Plot a plot
fig.add_subplot(212)
# Plot a plot
plt.show()

# %%
fig = plt.figure(figsize=(5,5))

fig.add_subplot(223)
fig.add_subplot(224)
# Plot a plot
fig.add_subplot(211)
# Plot a plot
plt.show()

# %%
fig = plt.figure(figsize=(5,5))

fig.add_subplot(222)
fig.add_subplot(224)
# Plot a plot
fig.add_subplot(121)
# Plot a plot
plt.show()

# %%
fig = plt.figure(figsize=(5,5))

fig.add_subplot(221)
fig.add_subplot(223)
# Plot a plot
fig.add_subplot(122)
# Plot a plot
plt.show()

# %%
fig = plt.figure(figsize=(13,13))
x=[1,2,3,4,5,6]
y=[7,8,9,1,2,3]
plot1=fig.add_subplot(221)
plot1.plot(x,y)
# Plot a plot
plot2=fig.add_subplot(222)
plot2.hist(x,bins=5)
# Plot a plot
plot3=fig.add_subplot(223)
plot3.scatter(x,y)
# Plot a plot
plot4=fig.add_subplot(224)
plot4.plot(x,y,'b*-')
# Plot a plot
plt.show()

# %%
plt.bar([1, 2, 3],[3,2,6])
plt.legend('A simple line')
plt.show()

# %%
plt.bar([1, 2, 3],[3,2,6])
plt.legend(['A simple line'])
plt.show()
